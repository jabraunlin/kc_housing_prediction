# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('kc_house_data.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
y = data.price

# %%
X = data[['bedrooms','bathrooms','sqft_living','yr_built','yr_renovated']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
lin = LinearRegression()
lin.fit(X_train, y_train)
lin_pred = lin.predict(X_test)
mean_absolute_error(y_test, lin_pred)
# Out:
# 157908.51419932878

# %%
plt.scatter(y_test, y_test - lin_pred, alpha=0.3)
plt.hlines(0,0, np.max(y_test))
plt.title('Residuals')
plt.savefig('lin_resids.png')

# %%
len(data[data.sqft_lot > data.sqft_living]['price'])
#len(data[data.sqft_lot <= data.sqft_living]['price'])
# Out:
# 20824

# %%
q = [ 0.25, 0.5, 0.75, 1]
prices = data.price.quantile(q)

# %%
prices
# Out:
# 0.25     321950.0
# 0.50     450000.0
# 0.75     645000.0
# 1.00    7700000.0
# Name: price, dtype: float64

# %%
low = data[data['price']<prices.iloc[0]]

# %%
midlow = data[(data['price']>prices.iloc[0])&(data['price']<prices.iloc[1])]
midhigh = data[(data['price']>prices.iloc[1])&(data['price']<prices.iloc[2])]
high = data[(data['price']>prices.iloc[2])&(data['price']<prices.iloc[3])]

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax.scatter(low.long, low.lat, alpha=0.5, s=5,label='q1')
ax.scatter(midlow.long, midlow.lat, alpha=0.5, s=5, label='q2')
ax.scatter(midhigh.long, midhigh.lat, alpha=0.5, s=5, label='q3')
ax.scatter(high.long, high.lat, alpha=0.5, s=5, label='q4')
plt.legend()
plt.savefig('lat_long.png')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms',y='price',data=data)
plt.savefig('bedrooms.png')

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
for houses in [low,midlow,midhigh,high]:
    ax.scatter(houses['sqft_living'],houses['sqft_lot'],alpha=0.3, s=20)
    ax.set_ylabel('Lot Sq. Ft.')
    ax.set_xlabel('Living Sq. Ft.')
    ax.set_xlim(0,8500)
    ax.set_ylim(0,500000)
plt.savefig('sqft_living_lot.png')

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['yr_built'],data['condition'],alpha=0.5)
plt.xlabel('Year Built')
plt.ylabel('Condition')
plt.savefig('yrbuilt_condition.png')

# %%
plt.figure(figsize=(10,10))
plt.scatter(data['date'],data['price'],alpha=0.5,s=10)
plt.ylim(0,4000000)
plt.xlabel('Date')
plt.ylabel('Price')
plt.savefig('price_over_time.png')

# %%
data.date = pd.to_datetime(data.date)
split_date = data.date.quantile(q=0.8)
X_train = data[data['date']<= split_date]
X_test = data[data['date'] > split_date]
y_train = X_train.price
y_test = X_test.price

# %%
avg_price = X_train.groupby(('bedrooms','bathrooms','zipcode')).mean()['price'].reset_index().rename(columns={'price':'avg_price'})

# %%
X_train = pd.merge(X_train,avg_price, how='left', on=['bedrooms','bathrooms','zipcode'])
X_test = pd.merge(X_test, avg_price, how='left',on=['bedrooms','bathrooms','zipcode'])

# %%
X_test.avg_price.fillna(np.mean(X_train['price'].values),inplace=True)

# %%
y_train = X_train.price
y_test = X_test.price
X_train = X_train.drop(columns=['price','date','id'])
X_test = X_test.drop(columns=['price','date','id'])

# %%
def neighbors_prediction(n):
    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(X_train[['long','lat']],y_train)
    idx = knn.kneighbors(X_test[['long','lat']])[1]
    preds = []
    for neighbors in range(len(idx)):
        X_train_neighbors = X_train.iloc[idx[neighbors]]
        y_train_neighbors = y_train.iloc[idx[neighbors]]
        lin = LinearRegression()
        lin.fit(X_train_neighbors, y_train_neighbors)
        preds.append(lin.predict(X_test.iloc[neighbors].reshape(1,-1))[0])
    return mean_absolute_error(y_test,np.array(preds))

# %%
errors = []
k_neighbors = [i for i in range(5,405)][::20]
for k in k_neighbors:
    errors.append(neighbors_prediction(k))

# %%
plt.plot(k_neighbors[1:], errors[1:])
plt.ylabel('Mean Abs Error')
plt.xlabel('K Neighbors')
plt.title('Choosing an Optimal K')
plt.savefig('choosing_k.png')

# %%
def neighbors_prediction(n):
    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(X_train[['long','lat']],y_train)
    idx = knn.kneighbors(X_test[['long','lat']])[1]
    preds = []
    for neighbors in range(len(idx)):
        X_train_neighbors = X_train.iloc[idx[neighbors]]
        y_train_neighbors = y_train.iloc[idx[neighbors]]
        rf = RandomForestRegressor(n_estimators=100, max_depth=7, n_jobs=-1)
        rf.fit(X_train_neighbors, y_train_neighbors)
        preds.append(rf.predict(X_test.iloc[neighbors].reshape(1,-1))[0])
    return mean_absolute_error(y_test,np.array(preds))

# %%
neighbors_prediction(200)
# Out:
# 80326.4815747592

# %%
plt.scatter(y_test, y_test - preds, alpha=0.3)
plt.hlines(0,0, np.max(y_test))
plt.title('Residuals')
pl
# Out:
# Text(0.5,1,'Residuals')
