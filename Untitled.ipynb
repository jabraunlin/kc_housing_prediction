# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv('kc_house_data.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
y = data.price

# %%
X = data[['bedrooms','bathrooms','sqft_living','yr_built','yr_renovated']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
lin = LinearRegression()
lin.fit(X_train, y_train)
lin_pred = lin.predict(X_test)
np.sqrt(mean_squared_error(y_test, lin_pred))
# Out:
# 233402.7734868058

# %%
plt.scatter(y_test, y_test - lin_pred, alpha=0.3)
plt.hlines(0,0, np.max(y_test))
plt.title('Residuals')
# Out:
# Text(0.5,1,'Residuals')

# %%
len(data[data.sqft_lot > data.sqft_living]['price'])
#len(data[data.sqft_lot <= data.sqft_living]['price'])
# Out:
# 20824

# %%
q = [ 0.25, 0.5, 0.75, 1]
prices = data.price.quantile(q)

# %%
prices
# Out:
# 0.25     321950.0
# 0.50     450000.0
# 0.75     645000.0
# 1.00    7700000.0
# Name: price, dtype: float64

# %%
low = data[data['price']<prices.iloc[0]]

# %%
midlow = data[(data['price']>prices.iloc[0])&(data['price']<prices.iloc[1])]
midhigh = data[(data['price']>prices.iloc[1])&(data['price']<prices.iloc[2])]
high = data[(data['price']>prices.iloc[2])&(data['price']<prices.iloc[3])]

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax.scatter(low.long, low.lat, alpha=0.5, s=5,label='q1')
ax.scatter(midlow.long, midlow.lat, alpha=0.5, s=5, label='q2')
ax.scatter(midhigh.long, midhigh.lat, alpha=0.5, s=5, label='q3')
ax.scatter(high.long, high.lat, alpha=0.5, s=5, label='q4')
plt.legend()

# %%
data.date = pd.to_datetime(data.date)
split_date = data.date.quantile(q=0.8)
X_train = data[data['date']<= split_date]
X_test = data[data['date'] > split_date]
y_train = X_train.price
y_test = X_test.price

# %%
avg_price = X_train.groupby(('bedrooms','bathrooms','zipcode')).mean()['price'].reset_index().rename(columns={'price':'avg_price'})

# %%
X_train = pd.merge(X_train,avg_price, how='left', on=['bedrooms','bathrooms','zipcode'])
X_test = pd.merge(X_test, avg_price, how='left',on=['bedrooms','bathrooms','zipcode'])

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train[['long','lat']],X_train['price'])
train_pred = knn.predict(X_train[['long','lat']])
test_pred = knn.predict(X_test[['long','lat']])
X_train['neighbors'] = train_pred
X_test['neighbors'] = test_pred

# %%
X_test.avg_price.fillna(np.mean(X_train['price'].values),inplace=True)

# %%
X_train = X_train.drop(columns=['price','date'])
X_test = X_test.drop(columns=['price','date'])

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=7, n_jobs=-1)
rf.fit(X_train, y_train)
pred = rf.predict(X_test)
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 206211.7788401211

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4257 entries, 0 to 4256
# Data columns (total 21 columns):
# id               4257 non-null int64
# bedrooms         4257 non-null int64
# bathrooms        4257 non-null float64
# sqft_living      4257 non-null int64
# sqft_lot         4257 non-null int64
# floors           4257 non-null float64
# waterfront       4257 non-null int64
# view             4257 non-null int64
# condition        4257 non-null int64
# grade            4257 non-null int64
# sqft_above       4257 non-null int64
# sqft_basement    4257 non-null int64
# yr_built         4257 non-null int64
# yr_renovated     4257 non-null int64
# zipcode          4257 non-null int64
# lat              4257 non-null float64
# long             4257 non-null float64
# sqft_living15    4257 non-null int64
# sqft_lot15       4257 non-null int64
# avg_price        4257 non-null float64
# neighbors        4257 non-null float64
# dtypes: float64(6), int64(15)
# ...

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
gbr_pred = gbr.predict(X_test)
mean_absolute_error(y_test, gbr_pred)
# Out:
# 97479.22315553037
